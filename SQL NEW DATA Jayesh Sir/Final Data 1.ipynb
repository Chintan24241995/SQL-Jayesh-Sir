# %%
import numpy as np

# %%
import pandas as pd

# %%
sales_23 = pd.read_csv('sales_2023.csv')

# %%
sales_24 = pd.read_csv('sales_2024.csv')

# %%
customer = pd.read_csv('customer_profiles.csv')

# %%
sales_23.head()
# Out:
#   Customer_ID Customer_Name Region_ID         Category  Q1_Sales  Q2_Sales  \
# 0   CUST-1001  Grace Nelson  R2_South         Clothing       819       903
# 1   CUST-1002    Danny Page   R3_East  Office Supplies       808       184
# 2   CUST-1003  Helen Hopper   R3_East  Office Supplies       806       876
# 3   CUST-1004    Trish Page   R3_East       Home Decor       269       239
# 4   CUST-1005  Karen Miller   R4_West  Office Supplies       936       925
#
#    Q3_Sales  Q4_Sales
# 0       317       465
# 1       319       327
# 2       542       689
# 3       944       881
# 4       783       190
