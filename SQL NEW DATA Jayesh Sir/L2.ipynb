# %%
import numpy as np
import pandas as pd

# %%
sr1 = pd.Series([1,2,3,4,5])
sr1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
sr1.iloc[4]
# Out:
# np.int64(5)

# %%
sr1.dtype
# Out:
# dtype('int64')

# %%
sr1.shape
# Out:
# (5,)

# %%
sr1.ndim
# Out:
# 1

# %%
sr2 = pd.Series([1,2,3,4,5], index= ['a','b','c','d','e'],name='RollNo')
sr2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: RollNo, dtype: int64

# %%
sr2.iloc[2]
# Out:
# np.int64(3)

# %%
sr2.loc['c']
# Out:
# np.int64(3)

# %%
sr = pd.Series([1,2.5,3,4,5,'a'])
sr
# Out:
# 0      1
# 1    2.5
# 2      3
# 3      4
# 4      5
# 5      a
# dtype: object

# %%
sr.dtype
# Out:
# dtype('O')

# %%
df1 = pd.DataFrame({'SrNo':[1,2,3,4,5],
                    'Name': ['a','b','c','d','e']})

# %%
df1
# Out:
#    SrNo Name
# 0     1    a
# 1     2    b
# 2     3    c
# 3     4    d
# 4     5    e

# %%
df2 = pd.DataFrame({'SrNo':[1,2,3,4,5],
                    'Name': ['a','b','c','d','e']}, index= [1,2,3,4,5])
df2
# Out:
#    SrNo Name
# 1     1    a
# 2     2    b
# 3     3    c
# 4     4    d
# 5     5    e

# %%
df2.iloc[0,1]
# Out:
# 'a'

# %%
df2.loc[1,'Name']
# Out:
# 'a'

# %%
df2.iloc[0:3,]
# Out:
#    SrNo Name
# 1     1    a
# 2     2    b
# 3     3    c

# %%
df2.loc[1:3,'SrNo']
# Out:
# 1    1
# 2    2
# 3    3
# Name: SrNo, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 1 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SrNo    5 non-null      int64
#  1   Name    5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 292.0+ bytes

# %% [markdown]
# Data cleaning was taught again using the L1 notebook.
